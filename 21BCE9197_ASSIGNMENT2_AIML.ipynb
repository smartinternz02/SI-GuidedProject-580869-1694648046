# %% [markdown]
# # ASSIGNMENT 2
#
# ## 21BCE9197
#
# ## HALEEMA SADHIA SYED

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sadhia = sns.load_dataset('car_crashes')
sadhia
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sadhia.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
sadhia.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
sadhia.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sadhia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
sadhia.info
# Out:
# <bound method DataFrame.info of     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sadhia.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
sadhia.isna().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
sadhia.isnull().any()
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %%
#SCATTERPLOT
sns.scatterplot(x="total", y="speeding", data=sadhia)
#Inference:  Above plot shows that as speeding increases total crashes is also increasing
# Out:
# <Axes: xlabel='total', ylabel='speeding'>

# %%
sns.scatterplot(x="total", y="alcohol", data=sadhia, color="r")
#Inference: Above plot shows that as alcohol increases total crashes is also increasing
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
sns.lineplot(x="total", y="not_distracted",data=sadhia, linestyle="--", color='red')
#Inference: Above plot shows that as not_distracted increases total crashes is also increasing
# Out:
# <Axes: xlabel='total', ylabel='not_distracted'>

# %%
#LINE PLOT
sns.lineplot(x="total", y="no_previous",data=sadhia)
#Inference: Above graph it is no of drivers increases with percetage in fatal collision who do not have previous accident
# Out:
# <Axes: xlabel='total', ylabel='no_previous'>

# %%
#DISTRIBUTION PLOT
sns.distplot(sadhia["ins_premium"])
#Inference:  Above graph it is true that the speeding is high at 300 to 900
# Out:
# <ipython-input-72-e1f31e266ffe>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sadhia["ins_premium"])
# <Axes: xlabel='ins_premium', ylabel='Density'>

# %%
#Relplot
sns.relplot(x="alcohol", y="speeding", data=sadhia , hue="ins_losses")
#Inference: Alcohol consumption is directly proportional to speeding

# %%
sns.relplot(x="alcohol", y="speeding", data=sadhia , hue="total")
#Inference: we can say that as speeding increases alcohol is also increasing

# %%
#BAR PLOT
plt.figure(figsize=(20, 18))
sns.barplot(x='abbrev', y='speeding', data=sadhia)
plt.show()
#Inference: ND has the total number of heighest collisions

# %%
df= df.sort_values(by='total', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x='abbrev', y='total', data=sadhia, palette='viridis')
#Inference: we can say that as abbrev 'SC' have higher total crashes among the remaining abbrev and the least one is 'DC'
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %%
#JOIN PLOT
sns.jointplot(x="total",y="speeding",data=sadhia)
#Inference:  we can say that as speeding and total crashes are increased at (12.5 , 4.1)

# %%
#BOX PLOT
sns.boxplot(x="total",y="alcohol",data=sadhia)
#Inference: we can say that as alcohol increases total crashes is also increasing
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
corr=sadhia.corr()
corr
sns.heatmap(corr,annot=True)
#Inference: we can say that >0.5 is highly correlated <0.5 is less correlated
# Out:
# <ipython-input-63-3895bddc49d9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=sadhia.corr()
# <Axes: >

# %%
tsc = sadhia['speeding'].sum()
tac = sadhia['alcohol'].sum()
toc = sadhia['total'].sum() - (tsc + tac)
labels = ['Speeding Crashes', 'Alcohol-Related Crashes', 'Other Crashes']
sizes = [tsc, tac, toc]
colors = ['blue', 'red', 'pink']
Explode=[0.1,0,0.2]
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, explode=Explode)
plt.title('Distribution of Crashes by Category')
plt.show()
#Inference: we can say that as other reason crashes greater than the Alcohol related Crashes & speeding crashes.
#Speeding crashes slightly greater than the Alcohol related Crashes. Here i explode the higher crashes at 0.2 and other one at 0.1 and the least one at same position.

# %%
#BAR PLOT
sns.barplot(sadhia['alcohol'])
plt.show()
#Inference: we can say that alcohol is just below 5
